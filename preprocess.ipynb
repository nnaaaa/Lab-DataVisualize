# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1.Data explorations
# 1. How many rows (observations) and columns (attributes) does the data have?
# 2. Are there any duplicate rows in the data?
# 3. What do the columns in the data mean?
# 4. What data type does each column currently have? (.dtype)numeric datatype

# %% [markdown]
# ### 1.1 How many rows (observations) and columns (attributes) does the data have for each day?

# %%
# Read
df1 = pd.read_csv('./data/covid_3_2_2023.csv')
df1.shape
# Out:
# (239, 21)

# %% [markdown]
# #### Because we need data for one week, we need to combine the data from each day into one dataframe.
# - Read in the data for each day
# - Add a column to the dataframe that indicates the day of the week
# - Combine the data into one dataframe

# %%
# Read all data
df1 = pd.read_csv('./data/covid_3_2_2023.csv')
df2 = pd.read_csv('./data/covid_3_3_2023.csv')
df3 = pd.read_csv('./data/covid_3_4_2023.csv')
df4 = pd.read_csv('./data/covid_3_5_2023.csv')
df5 = pd.read_csv('./data/covid_3_6_2023.csv')

# %%
# Add Date column 
def add_date(df, date):
    df['Date'] = pd.to_datetime(date, format='%Y-%m-%d')
    
    # move the date column to second position
    cols = df.columns.tolist()
    cols = cols[:1] + cols[-1:] + cols[1:-1]
    return df[cols]

df1 = add_date(df1, '2023-03-02')
df2 = add_date(df2, '2023-03-03')
df3 = add_date(df3, '2023-03-04')
df4 = add_date(df4, '2023-03-05')
df5 = add_date(df5, '2023-03-06')

# %%
# Concatenate all dataframes
new_df = pd.concat([df1, df2, df3, df4, df5], axis=0, ignore_index=True)

# Sort rows by country name and date
new_df = new_df.sort_values(by=['Country,Other', 'Date'])

# %%
# Shape of new dataframe 
new_df.shape
# Out:
# (1195, 22)

# %%
# save the new dataframe
new_df.to_csv('./data/combined_data.csv', index=False)
new_df.head(10)
# Out:
#      Country,Other       Date  TotalCases NewCases TotalDeaths  NewDeaths  \
# 121    Afghanistan 2023-03-02     209,359      +19       7,896        NaN
# 360    Afghanistan 2023-03-03     209,362       +3       7,896        NaN
# 599    Afghanistan 2023-03-04     209,370       +4       7,896        NaN
# 838    Afghanistan 2023-03-05     209,390      +20       7,896        NaN
# 1076   Afghanistan 2023-03-06     209,390      NaN       7,896        NaN
# 5           Africa 2023-03-02  12,795,801     +732     258,590        NaN
# 244         Africa 2023-03-03  12,796,326     +525     258,590        NaN
# 483         Africa 2023-03-04  12,796,404      +78     258,590        NaN
# 722         Africa 2023-03-05  12,796,571     +167     258,593        3.0
# 961         Africa 2023-03-06  12,796,571      NaN     258,593        NaN
#
#      TotalRecovered NewRecovered ActiveCases Serious,Critical  ... TotalTests  \
# 121         191,166          +10      10,297               45  ...  1,201,475
# 360         191,170           +4      10,296               45  ...  1,201,744
# 599         191,181           +7      10,293               45  ...  1,202,018
# 838         191,212          +31      10,282               45  ...  1,202,290
# 1076        191,212          NaN      10,282               45  ...  1,202,290
# 5        12,076,247         +132     460,964              548  ...        NaN
# 244      12,076,332          +85     461,404              548  ...        NaN
# 483      12,076,449         +117     461,365              548  ...        NaN
# 722      12,076,616         +167     461,362              548  ...        NaN
# 961      12,076,624           +8     461,354              548  ...        NaN
#
#      Tests/\r\n1M pop  Population Continent 1 Caseevery X ppl  \
# 121            29,481  40,754,388      Asia               195
# 360            29,487  40,754,388      Asia               195
# 599            29,494  40,754,388      Asia               195
# 838            29,501  40,754,388      Asia               195
# 1076           29,501  40,754,388      Asia               195
# 5                 NaN         NaN    Africa               NaN
# 244               NaN         NaN    Africa               NaN
# 483               NaN         NaN    Africa               NaN
# 722               NaN         NaN    Africa               NaN
# 961               NaN         NaN    Africa               NaN
#
#      1 Deathevery X ppl 1 Testevery X ppl New Cases/1M pop  New Deaths/1M pop  \
# 121               5,161              34.0              0.5                NaN
# 360               5,161              34.0             0.07                NaN
# 599               5,161              34.0              0.1                NaN
# 838               5,161              34.0              0.5                NaN
# 1076              5,161              34.0              NaN                NaN
# 5                   NaN               NaN              NaN                NaN
# 244                 NaN               NaN              NaN                NaN
# 483                 NaN               NaN              NaN                NaN
# 722                 NaN               NaN              NaN                NaN
# 961                 NaN               NaN              NaN                NaN
#
#      Active Cases/1M pop
# 121                  253
# 360                  253
# 599                  253
# 838                  252
# 1076                 252
# 5                    NaN
# 244                  NaN
# 483                  NaN
# 722                  NaN
# 961                  NaN
#
# [10 rows x 22 columns]

# %% [markdown]
# ### 1.2 Are there any duplicate rows in the data?

# %%
new_df[new_df.duplicated()].shape
# Out:
# (0, 22)

# %% [markdown]
# - The data has no duplicate rows

# %% [markdown]
# ### 1.3 What do the columns in the data mean?
# - The columns in the data are the following:
#     - **Country**: The country
#     - **Date**: The date
#     - **TotalCases**: The total cases
#     - **NewCases**: The new cases
#     - **TotalDeaths**: The total deaths
#     - **NewDeaths**: The new deaths
#     - **TotalRecovered**: The total recovered
#     - **NewRecovered**: The new recovered
#     - **ActiveCases**: The active cases
#     - **Serious,Critical**: The serious, critical
#     - **TotalCases/1M pop**: The total cases per 1 million population
#     - **Deaths/1M pop**: The total deaths per 1 million population
#     - **TotalTests**: The total tests
#     - **Tests/1M pop**: The total tests per 1 million population
#     - **Population**: The population
#     - **Continent**: The continent
#     - **1 Caseevery X ppl**: The ratio for every X people. for example, 1 Caseevery X ppl is 3 means that 3 people have 1 case
#     - **1 Deathevery X ppl**: The ratio deaths for every people.
#     - **1 Testevery  X ppl**: The ratio tests for every people.
#     - **New Cases/1M pop**: the new cases per 1 million population
#     - **New Deaths/1M pop**: The new deaths per 1 million population
#     - **Active Cases/1M pop**: The active cases per 1 million population

# %% [markdown]
# ### 1.4 What data type does each column currently have?

# %%
new_df.dtypes
# Out:
# Country,Other                  object
# Date                   datetime64[ns]
# TotalCases                     object
# NewCases                       object
# TotalDeaths                    object
# NewDeaths                     float64
# TotalRecovered                 object
# NewRecovered                   object
# ActiveCases                    object
# Serious,Critical               object
# Tot Cases/1M pop               object
# Deaths/1M pop                  object
# TotalTests                     object
# Tests/\r\n1M pop               object
# Population                     object
# Continent                      object
# 1 Caseevery X ppl              object
# 1 Deathevery X ppl             object
# 1 Testevery X ppl             float64
# New Cases/1M pop               object
# New Deaths/1M pop             float64
# Active Cases/1M pop            object
# dtype: object

# %% [markdown]
# **Issues that need to be preprocessed:**
# - Rename the columns to be more descriptive
# - Handle missing values
# - Change the data type of the columns to be numeric
# - Handle values such as +19, +1 or have ',' in values.
# - Delete columns that are dependent attributes.

# %% [markdown]
# ## 2. Preprocessing

# %% [markdown]
# ### 2.1 Rename the columns to be more descriptive

# %%
# Rename the col    
new_df = new_df.rename(columns={'Country,Other': 'Country'})
new_df = new_df.rename(columns={'Tot\xa0Cases/1M pop': 'TotalCases/1M pop'})
new_df = new_df.rename(columns={'Tests/\r\n1M pop': 'Tests/1M pop'})

# %% [markdown]
# ### 2.2 Handle missing values

# %%
new_df.isnull().sum()
# Out:
# Country                   5
# Date                      0
# TotalCases                0
# NewCases                955
# TotalDeaths              30
# NewDeaths              1063
# TotalRecovered          105
# NewRecovered            946
# ActiveCases              95
# Serious,Critical        524
# TotalCases/1M pop        45
# Deaths/1M pop            75
# TotalTests              130
# Tests/1M pop            130
# Population               50
# Continent                15
# 1 Caseevery X ppl        50
# 1 Deathevery X ppl       80
# 1 Testevery X ppl       130
# New Cases/1M pop        983
# New Deaths/1M pop      1088
# Active Cases/1M pop      91
# dtype: int64

# %% [markdown]
# #### 2.2.1 Delete rows with missing Country values and Country values that are not in continents

# %%
# delete the rows with null country names
new_df = new_df.dropna(subset=['Country'])
new_df.shape
# Out:
# (1190, 22)

# %%
new_df[new_df['Continent'].isnull()]
# Out:
#                Country       Date TotalCases NewCases TotalDeaths  NewDeaths  \
# 234   Diamond Princess 2023-03-02        712      NaN          13        NaN
# 473   Diamond Princess 2023-03-03        712      NaN          13        NaN
# 712   Diamond Princess 2023-03-04        712      NaN          13        NaN
# 951   Diamond Princess 2023-03-05        712      NaN          13        NaN
# 1189  Diamond Princess 2023-03-06        712      NaN          13        NaN
# 237         MS Zaandam 2023-03-02          9      NaN           2        NaN
# 476         MS Zaandam 2023-03-03          9      NaN           2        NaN
# 715         MS Zaandam 2023-03-04          9      NaN           2        NaN
# 954         MS Zaandam 2023-03-05          9      NaN           2        NaN
# 1192        MS Zaandam 2023-03-06          9      NaN           2        NaN
#
#      TotalRecovered NewRecovered ActiveCases Serious,Critical  ... TotalTests  \
# 234             699          NaN           0              NaN  ...        NaN
# 473             699          NaN           0              NaN  ...        NaN
# 712             699          NaN           0              NaN  ...        NaN
# 951             699          NaN           0              NaN  ...        NaN
# 1189            699          NaN           0              NaN  ...        NaN
# 237               7          NaN           0              NaN  ...        NaN
# 476               7          NaN           0              NaN  ...        NaN
# 715               7          NaN           0              NaN  ...        NaN
# 954               7          NaN           0              NaN  ...        NaN
# 1192              7          NaN           0              NaN  ...        NaN
#
#      Tests/1M pop Population Continent 1 Caseevery X ppl 1 Deathevery X ppl  \
# 234           NaN        NaN       NaN               NaN                NaN
# 473           NaN        NaN       NaN               NaN                NaN
# 712           NaN        NaN       NaN               NaN                NaN
# 951           NaN        NaN       NaN               NaN                NaN
# 1189          NaN        NaN       NaN               NaN                NaN
# 237           NaN        NaN       NaN               NaN                NaN
# 476           NaN        NaN       NaN               NaN                NaN
# 715           NaN        NaN       NaN               NaN                NaN
# 954           NaN        NaN       NaN               NaN                NaN
# 1192          NaN        NaN       NaN               NaN                NaN
#
#      1 Testevery X ppl New Cases/1M pop  New Deaths/1M pop Active Cases/1M pop
# 234                NaN              NaN                NaN                 NaN
# 473                NaN              NaN                NaN                 NaN
# 712                NaN              NaN                NaN                 NaN
# 951                NaN              NaN                NaN                 NaN
# 1189               NaN              NaN                NaN                 NaN
# 237                NaN              NaN                NaN                 NaN
# 476                NaN              NaN                NaN                 NaN
# 715                NaN              NaN                NaN                 NaN
# 954                NaN              NaN                NaN                 NaN
# 1192               NaN              NaN                NaN                 NaN
#
# [10 rows x 22 columns]

# %%
# So need to delete 'Diamond Princess', 'MS Zaandam' country 
new_df = new_df[~new_df['Country'].str.contains('Diamond Princess')]
new_df = new_df[~new_df['Country'].str.contains('MS Zaandam')]
new_df.shape
# Out:
# (1180, 22)

# %%
new_df.isnull().sum()
# Out:
# Country                   0
# Date                      0
# TotalCases                0
# NewCases                940
# TotalDeaths              30
# NewDeaths              1048
# TotalRecovered          105
# NewRecovered            931
# ActiveCases              95
# Serious,Critical        514
# TotalCases/1M pop        30
# Deaths/1M pop            60
# TotalTests              115
# Tests/1M pop            115
# Population               35
# Continent                 0
# 1 Caseevery X ppl        35
# 1 Deathevery X ppl       65
# 1 Testevery X ppl       115
# New Cases/1M pop        968
# New Deaths/1M pop      1073
# Active Cases/1M pop      76
# dtype: int64

# %% [markdown]
# #### 2.2.2 Delete rows missing population values

# %%
new_df[new_df['Population'].isnull()]
# Out:
#            Country       Date   TotalCases  NewCases TotalDeaths  NewDeaths  \
# 5           Africa 2023-03-02   12,795,801      +732     258,590        NaN
# 244         Africa 2023-03-03   12,796,326      +525     258,590        NaN
# 483         Africa 2023-03-04   12,796,404       +78     258,590        NaN
# 722         Africa 2023-03-05   12,796,571      +167     258,593        3.0
# 961         Africa 2023-03-06   12,796,571       NaN     258,593        NaN
# 0             Asia 2023-03-02  214,400,666   +36,069   1,536,954      177.0
# 239           Asia 2023-03-03  214,439,390   +38,724   1,537,144      190.0
# 478           Asia 2023-03-04  214,474,748   +35,043   1,537,331      184.0
# 717           Asia 2023-03-05  214,505,850   +31,102   1,537,487      156.0
# 957           Asia 2023-03-06  214,510,150    +4,300   1,537,496        9.0
# 2           Europe 2023-03-02  246,491,769   +50,866   2,019,047      290.0
# 241         Europe 2023-03-03  246,522,121   +30,352   2,019,164      117.0
# 480         Europe 2023-03-04  246,559,822   +29,055   2,019,349       66.0
# 719         Europe 2023-03-05  246,578,819   +18,997   2,019,405       56.0
# 958         Europe 2023-03-06  246,578,819       NaN   2,019,405        NaN
# 1    North America 2023-03-02  124,703,471   +19,249   1,612,428      180.0
# 240  North America 2023-03-03  124,712,309    +8,838   1,612,522       94.0
# 479  North America 2023-03-04  124,725,126   +12,817   1,612,592       70.0
# 718  North America 2023-03-05  124,727,196    +2,070   1,612,598        6.0
# 956  North America 2023-03-06  124,727,196       NaN   1,612,598        NaN
# 4          Oceania 2023-03-02   14,013,064    +2,747      26,191       13.0
# 243        Oceania 2023-03-03   14,015,805    +2,741      26,203       12.0
# 482        Oceania 2023-03-04   14,015,805       NaN      26,203        NaN
# 721        Oceania 2023-03-05   14,015,805       NaN      26,203        NaN
# 960        Oceania 2023-03-06   14,015,805       NaN      26,203        NaN
# 3    South America 2023-03-02   68,030,067    +6,716   1,350,809       62.0
# 242  South America 2023-03-03   68,042,673   +12,606   1,350,906       97.0
# 481  South America 2023-03-04   68,045,906    +3,213   1,350,925       19.0
# 720  South America 2023-03-05   68,048,725    +2,819   1,350,941       16.0
# 959  South America 2023-03-06   68,048,725       NaN   1,350,941        NaN
# 7            World 2023-03-02  680,435,559  +116,379   6,804,034      722.0
# 246          World 2023-03-03  680,529,345   +93,786   6,804,544      510.0
# 485          World 2023-03-04  680,618,532   +80,206   6,805,005      339.0
# 724          World 2023-03-05  680,673,687   +55,155   6,805,242      237.0
# 963          World 2023-03-06  680,677,987    +4,300   6,805,251        9.0
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical  ... TotalTests  \
# 5       12,076,247         +132     460,964              548  ...        NaN
# 244     12,076,332          +85     461,404              548  ...        NaN
# 483     12,076,449         +117     461,365              548  ...        NaN
# 722     12,076,616         +167     461,362              548  ...        NaN
# 961     12,076,624           +8     461,354              548  ...        NaN
# 0      199,025,596      +36,820  13,838,116           15,470  ...        NaN
# 239    199,055,199      +29,603  13,847,047           15,462  ...        NaN
# 478    199,108,904      +53,531  13,828,513           15,464  ...        NaN
# 717    199,139,502      +30,598  13,828,861           15,506  ...        NaN
# 957    199,139,436          NaN  13,833,218           15,511  ...        NaN
# 2      242,020,924      +49,140   2,451,798            6,481  ...        NaN
# 241    242,067,073      +46,149   2,435,884            6,492  ...        NaN
# 480    242,097,829      +29,348   2,442,644            6,481  ...        NaN
# 719    242,122,675      +24,846   2,436,739            6,479  ...        NaN
# 958    242,131,392       +8,717   2,428,022            6,479  ...        NaN
# 1      119,938,550      +49,916   3,152,493            7,725  ...        NaN
# 240    119,996,558      +58,008   3,103,229            7,890  ...        NaN
# 479    120,020,408      +23,850   3,092,126            7,890  ...        NaN
# 718    120,025,213       +4,805   3,089,385            7,890  ...        NaN
# 956    120,026,743       +1,530   3,087,855            7,892  ...        NaN
# 4       13,849,802       +2,549     137,071               64  ...        NaN
# 243     13,852,354       +2,552     137,248               55  ...        NaN
# 482     13,852,354          NaN     137,248               55  ...        NaN
# 721     13,852,354          NaN     137,248               55  ...        NaN
# 960     13,852,354          NaN     137,248               55  ...        NaN
# 3       66,284,851       +2,480     394,407           10,187  ...        NaN
# 242     66,293,458       +8,607     398,309           10,191  ...        NaN
# 481     66,293,845         +383     401,136           10,186  ...        NaN
# 720     66,301,273       +7,428     396,511           10,185  ...        NaN
# 959     66,301,265          NaN     396,519           10,185  ...        NaN
# 7      653,196,676     +141,037  20,434,849           40,475  ...        NaN
# 246    653,341,680     +145,004  20,383,121           40,638  ...        NaN
# 485    653,450,495     +107,229  20,363,032           40,624  ...        NaN
# 724    653,518,339      +67,844  20,350,106           40,663  ...        NaN
# 963    653,528,520      +10,181  20,344,216           40,670  ...        NaN
#
#     Tests/1M pop Population          Continent 1 Caseevery X ppl  \
# 5            NaN        NaN             Africa               NaN
# 244          NaN        NaN             Africa               NaN
# 483          NaN        NaN             Africa               NaN
# 722          NaN        NaN             Africa               NaN
# 961          NaN        NaN             Africa               NaN
# 0            NaN        NaN               Asia               NaN
# 239          NaN        NaN               Asia               NaN
# 478          NaN        NaN               Asia               NaN
# 717          NaN        NaN               Asia               NaN
# 957          NaN        NaN               Asia               NaN
# 2            NaN        NaN             Europe               NaN
# 241          NaN        NaN             Europe               NaN
# 480          NaN        NaN             Europe               NaN
# 719          NaN        NaN             Europe               NaN
# 958          NaN        NaN             Europe               NaN
# 1            NaN        NaN      North America               NaN
# 240          NaN        NaN      North America               NaN
# 479          NaN        NaN      North America               NaN
# 718          NaN        NaN      North America               NaN
# 956          NaN        NaN      North America               NaN
# 4            NaN        NaN  Australia/Oceania               NaN
# 243          NaN        NaN  Australia/Oceania               NaN
# 482          NaN        NaN  Australia/Oceania               NaN
# 721          NaN        NaN  Australia/Oceania               NaN
# 960          NaN        NaN  Australia/Oceania               NaN
# 3            NaN        NaN      South America               NaN
# 242          NaN        NaN      South America               NaN
# 481          NaN        NaN      South America               NaN
# 720          NaN        NaN      South America               NaN
# 959          NaN        NaN      South America               NaN
# 7            NaN        NaN                All               NaN
# 246          NaN        NaN                All               NaN
# 485          NaN        NaN                All               NaN
# 724          NaN        NaN                All               NaN
# 963          NaN        NaN                All               NaN
#
#     1 Deathevery X ppl 1 Testevery X ppl New Cases/1M pop  New Deaths/1M pop  \
# 5                  NaN               NaN              NaN                NaN
# 244                NaN               NaN              NaN                NaN
# 483                NaN               NaN              NaN                NaN
# 722                NaN               NaN              NaN                NaN
# 961                NaN               NaN              NaN                NaN
# 0                  NaN               NaN              NaN                NaN
# 239                NaN               NaN              NaN                NaN
# 478                NaN               NaN              NaN                NaN
# 717                NaN               NaN              NaN                NaN
# 957                NaN               NaN              NaN                NaN
# 2                  NaN               NaN              NaN                NaN
# 241                NaN               NaN              NaN                NaN
# 480                NaN               NaN              NaN                NaN
# 719                NaN               NaN              NaN                NaN
# 958                NaN               NaN              NaN                NaN
# 1                  NaN               NaN              NaN                NaN
# 240                NaN               NaN              NaN                NaN
# 479                NaN               NaN              NaN                NaN
# 718                NaN               NaN              NaN                NaN
# 956                NaN               NaN              NaN                NaN
# 4                  NaN               NaN              NaN                NaN
# 243                NaN               NaN              NaN                NaN
# 482                NaN               NaN              NaN                NaN
# 721                NaN               NaN              NaN                NaN
# 960                NaN               NaN              NaN                NaN
# 3                  NaN               NaN              NaN                NaN
# 242                NaN               NaN              NaN                NaN
# 481                NaN               NaN              NaN                NaN
# 720                NaN               NaN              NaN                NaN
# 959                NaN               NaN              NaN                NaN
# 7                  NaN               NaN              NaN                NaN
# 246                NaN               NaN              NaN                NaN
# 485                NaN               NaN              NaN                NaN
# 724                NaN               NaN              NaN                NaN
# 963                NaN               NaN              NaN                NaN
#
#     Active Cases/1M pop
# 5                   NaN
# 244                 NaN
# 483                 NaN
# 722                 NaN
# 961                 NaN
# 0                   NaN
# 239                 NaN
# 478                 NaN
# 717                 NaN
# 957                 NaN
# 2                   NaN
# 241                 NaN
# 480                 NaN
# 719                 NaN
# 958                 NaN
# 1                   NaN
# 240                 NaN
# 479                 NaN
# 718                 NaN
# 956                 NaN
# 4                   NaN
# 243                 NaN
# 482                 NaN
# 721                 NaN
# 960                 NaN
# 3                   NaN
# 242                 NaN
# 481                 NaN
# 720                 NaN
# 959                 NaN
# 7                   NaN
# 246                 NaN
# 485                 NaN
# 724                 NaN
# 963                 NaN
#
# [35 rows x 22 columns]

# %% [markdown]
# - Null population because there are rows that calculate the total number in each region such as Asia, Europe, North America, etc, we can remove these rows.

# %%
# remove the rows with null population
new_df = new_df[~new_df['Population'].isnull()]

# %% [markdown]
# #### 2.2.3. Delete dependent attributes such as TotalCases/1M pop, TotalDeaths/1M pop, etc. Because we can calculate these values from TotalCases, TotalDeaths and population. For example, TotalCases/1M pop = TotalCases / Population

# %%
new_df = new_df.drop(columns=['TotalCases/1M pop', 'Tests/1M pop', 'Deaths/1M pop', 'New Cases/1M pop', 'New Deaths/1M pop'])
new_df.head(5)
# Out:
#           Country       Date TotalCases NewCases TotalDeaths  NewDeaths  \
# 121   Afghanistan 2023-03-02    209,359      +19       7,896        NaN
# 360   Afghanistan 2023-03-03    209,362       +3       7,896        NaN
# 599   Afghanistan 2023-03-04    209,370       +4       7,896        NaN
# 838   Afghanistan 2023-03-05    209,390      +20       7,896        NaN
# 1076  Afghanistan 2023-03-06    209,390      NaN       7,896        NaN
#
#      TotalRecovered NewRecovered ActiveCases Serious,Critical TotalTests  \
# 121         191,166          +10      10,297               45  1,201,475
# 360         191,170           +4      10,296               45  1,201,744
# 599         191,181           +7      10,293               45  1,202,018
# 838         191,212          +31      10,282               45  1,202,290
# 1076        191,212          NaN      10,282               45  1,202,290
#
#       Population Continent 1 Caseevery X ppl 1 Deathevery X ppl  \
# 121   40,754,388      Asia               195              5,161
# 360   40,754,388      Asia               195              5,161
# 599   40,754,388      Asia               195              5,161
# 838   40,754,388      Asia               195              5,161
# 1076  40,754,388      Asia               195              5,161
#
#       1 Testevery X ppl Active Cases/1M pop
# 121                34.0                 253
# 360                34.0                 253
# 599                34.0                 253
# 838                34.0                 252
# 1076               34.0                 252

# %%
new_df.isnull().sum()
# Out:
# Country                   0
# Date                      0
# TotalCases                0
# NewCases                933
# TotalDeaths              30
# NewDeaths              1038
# TotalRecovered          105
# NewRecovered            926
# ActiveCases              95
# Serious,Critical        514
# TotalTests               80
# Population                0
# Continent                 0
# 1 Caseevery X ppl         0
# 1 Deathevery X ppl       30
# 1 Testevery X ppl        80
# Active Cases/1M pop      41
# dtype: int64

# %% [markdown]
# ### 2.3 Handle values such as +19, +1 or have ',' in values.

# %%
# remove all , in values
new_df['TotalCases'] = new_df['TotalCases'].str.replace(',', '')
new_df['NewCases'] = new_df['NewCases'].str.replace(r'[+,]', '')
new_df['TotalDeaths'] = new_df['TotalDeaths'].str.replace(',', '')
new_df['TotalRecovered'] = new_df['TotalRecovered'].str.replace(',', '')
new_df['NewRecovered'] = new_df['NewRecovered'].str.replace(r'[+,]', '')
new_df['ActiveCases'] = new_df['ActiveCases'].str.replace(',', '')
new_df['Serious,Critical'] = new_df['Serious,Critical'].str.replace(',', '')
new_df['TotalTests'] = new_df['TotalTests'].str.replace(',', '')
new_df['Population'] = new_df['Population'].str.replace(',', '')
new_df['Active Cases/1M pop'] = new_df['Active Cases/1M pop'].str.replace(',', '')
# Out:
# /tmp/ipykernel_5618/2319826667.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   new_df['NewCases'] = new_df['NewCases'].str.replace(r'[+,]', '')
# /tmp/ipykernel_5618/2319826667.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   new_df['NewRecovered'] = new_df['NewRecovered'].str.replace(r'[+,]', '')

# %%
# fill the missing values with 0 
new_df[['NewCases', 'NewDeaths', 'NewRecovered','Serious,Critical', 'Active Cases/1M pop']] = new_df[['NewCases', 'NewDeaths','NewRecovered','Serious,Critical', 'Active Cases/1M pop']].fillna(0)
new_df.isnull().sum()
# Out:
# Country                  0
# Date                     0
# TotalCases               0
# NewCases                 0
# TotalDeaths             30
# NewDeaths                0
# TotalRecovered         105
# NewRecovered             0
# ActiveCases             95
# Serious,Critical         0
# TotalTests              80
# Population               0
# Continent                0
# 1 Caseevery X ppl        0
# 1 Deathevery X ppl      30
# 1 Testevery X ppl       80
# Active Cases/1M pop      0
# dtype: int64

# %%
# change the data type of columns to numeric
new_df['ActiveCases'] = pd.to_numeric(new_df['ActiveCases'])
new_df['Active Cases/1M pop'] = pd.to_numeric(new_df['Active Cases/1M pop'])
new_df['Population'] = pd.to_numeric(new_df['Population'])
new_df['TotalCases'] = pd.to_numeric(new_df['TotalCases'])
new_df['TotalDeaths'] = pd.to_numeric(new_df['TotalDeaths'])
new_df['TotalRecovered'] = pd.to_numeric(new_df['TotalRecovered'])
new_df['NewCases'] = pd.to_numeric(new_df['NewCases'])
new_df['NewDeaths'] = pd.to_numeric(new_df['NewDeaths'])
new_df['NewRecovered'] = pd.to_numeric(new_df['NewRecovered'])
new_df['Serious,Critical'] = pd.to_numeric(new_df['Serious,Critical'])
new_df['TotalTests'] = pd.to_numeric(new_df['TotalTests'])
    
new_df.dtypes
# Out:
# Country                        object
# Date                   datetime64[ns]
# TotalCases                      int64
# NewCases                        int64
# TotalDeaths                   float64
# NewDeaths                     float64
# TotalRecovered                float64
# NewRecovered                    int64
# ActiveCases                   float64
# Serious,Critical                int64
# TotalTests                    float64
# Population                      int64
# Continent                      object
# 1 Caseevery X ppl              object
# 1 Deathevery X ppl             object
# 1 Testevery X ppl             float64
# Active Cases/1M pop           float64
# dtype: object

# %% [markdown]
# #### 2.3.0 Delete rows with outliers such as population < 1000000 or total deaths could not be updated for a long time.

# %%
# we can remove the rows with null values in TotalDeaths and population < 1000000
new_df = new_df[~new_df['TotalDeaths'].isnull()]
new_df = new_df[~(new_df['Population'] < 1000000)]

# %% [markdown]
# #### 2.3.1. Fill in missing ActiveCase with formula: **ActiveCase = ActiveCase/1M pop * Population / 1000000**

# %%
new_df['ActiveCases'] = new_df['ActiveCases'].fillna(round(new_df['Active Cases/1M pop'] * new_df['Population'] / 1000000, 0))

# %% [markdown]
# #### 2.3.2 Fill missing TotalRecovered with formula: **TotalCases = TotalRecovered + ActiveCases + TotalDeaths**

# %%
new_df['TotalRecovered'] = new_df['TotalRecovered'].fillna(round(new_df['TotalCases'] - new_df['TotalDeaths'] - new_df['ActiveCases'], 0))

# %% [markdown]
# #### 2.3.3 Fill missing values of 1 test every X ppl by mean of 1 test every X ppl in the same continent

# %%
# fill the missing values with the mean of each continent
new_df['1 Testevery X ppl'] = new_df.groupby('Continent')['1 Testevery X ppl'].transform(lambda x: x.fillna(round(x.mean(),0)))

# %% [markdown]
# #### 2.3.4 Fill missing values of TotalTests by formula: **TotalTests = Population / 1 Testevery X ppl**

# %%
# replace all missing values in TotalTests with division of population and 1 Testevery X ppl
new_df['TotalTests'] = new_df['TotalTests'].fillna(round(new_df['Population'] / new_df['1 Testevery X ppl'], 0))

# %%
new_df.isnull().sum()
# Out:
# Country                0
# Date                   0
# TotalCases             0
# NewCases               0
# TotalDeaths            0
# NewDeaths              0
# TotalRecovered         0
# NewRecovered           0
# ActiveCases            0
# Serious,Critical       0
# TotalTests             0
# Population             0
# Continent              0
# 1 Caseevery X ppl      0
# 1 Deathevery X ppl     0
# 1 Testevery X ppl      0
# Active Cases/1M pop    0
# dtype: int64

# %% [markdown]
# ### 2.5 Delete columns that are not necessary such as dependent attributes.

# %% [markdown]
# - There are 4 columns that can calculate from another columns such as 1 Caseevery X ppl, 1 Deathevery X ppl, 1 Testevery  X ppl, Active Cases/1M pop. We can delete these columns.

# %%
# delete 4 last columns
new_df = new_df.drop(columns=['1 Testevery X ppl', '1 Deathevery X ppl', '1 Testevery X ppl','Active Cases/1M pop'])
new_df.head(10)
# Out:
#           Country       Date  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 121   Afghanistan 2023-03-02      209359        19       7896.0        0.0
# 360   Afghanistan 2023-03-03      209362         3       7896.0        0.0
# 599   Afghanistan 2023-03-04      209370         4       7896.0        0.0
# 838   Afghanistan 2023-03-05      209390        20       7896.0        0.0
# 1076  Afghanistan 2023-03-06      209390         0       7896.0        0.0
# 109       Albania 2023-03-02      334408         0       3596.0        0.0
# 348       Albania 2023-03-03      334427        19       3597.0        1.0
# 587       Albania 2023-03-04      334427         0       3597.0        0.0
# 826       Albania 2023-03-05      334427         0       3597.0        0.0
# 1064      Albania 2023-03-06      334427         0       3597.0        0.0
#
#       TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  TotalTests  \
# 121         191166.0            10      10297.0                45   1201475.0
# 360         191170.0             4      10296.0                45   1201744.0
# 599         191181.0             7      10293.0                45   1202018.0
# 838         191212.0            31      10282.0                45   1202290.0
# 1076        191212.0             0      10282.0                45   1202290.0
# 109         329152.0             0       1660.0                 0   1941032.0
# 348         329169.0            17       1661.0                 0   1941032.0
# 587         329169.0             0       1661.0                 0   1941032.0
# 826         329169.0             0       1661.0                 0   1941032.0
# 1064        329169.0             0       1661.0                 0   1941032.0
#
#       Population Continent 1 Caseevery X ppl
# 121     40754388      Asia               195
# 360     40754388      Asia               195
# 599     40754388      Asia               195
# 838     40754388      Asia               195
# 1076    40754388      Asia               195
# 109      2866374    Europe                 9
# 348      2866374    Europe                 9
# 587      2866374    Europe                 9
# 826      2866374    Europe                 9
# 1064     2866374    Europe                 9

# %%
# shape of new dataframe after cleaning
new_df.shape
# Out:
# (790, 14)

# %%
# save to csv
new_df.to_csv('./data/final_data.csv', index=False)
